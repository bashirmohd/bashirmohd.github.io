# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib
from pylab import *
# %matplotlib inline
import matplotlib.pyplot as plt
plt.rcParams.update({'font.size': 40})
plt.rcParams["font.weight"] = "bold"
plt.rcParams["axes.labelweight"] = "bold"
rc('axes', linewidth=3)

# %%
pwd
# Out:
# '/Users/bashirm/Documents/largefiles'

# %%
df = pd.read_csv('combine_plot_buffersize_128.csv')

# %%
df.head()
# Out:
#    sn  Throughput_5mb  Throughput_10mb  Throughput_20mb  Throughput_50mb  \
# 0   0        0.000000         0.000000         0.000000         0.000000
# 1   1        0.255936         0.204759         0.204759         0.170638
# 2   2        0.341220         0.204759         0.204759         0.170638
# 3   3        0.255936         0.170638         0.093082         0.146265
# 4   4        0.255936         0.204759         0.170638         0.170638
#
#    Throughput_100mb
# 0          0.000000
# 1          0.113765
# 2          0.102390
# 3          0.127984
# 4          0.127984

# %%
df.plot("sn", ["Throughput_5mb"],linewidth=3,figsize=(21,13))
plt.xlabel("Time(s)",)
# Out:
# Text(0.5, 0, 'Time(s)')

# %%
df.plot("sn", ["Throughput_10mb"],linewidth=3,figsize=(21,13))
plt.xlabel("Time(s)")
plt.ylabel('Throughput (Mbps)')
# Out:
# Text(0, 0.5, 'Throughput (Mbps)')

# %%
df.plot("sn", ["Throughput_20mb"],linewidth=3,figsize=(21,13))
plt.xlabel("Time(s)")
plt.ylabel('Throughput (Mbps)')
# Out:
# Text(0, 0.5, 'Throughput (Mbps)')

# %%
df.plot("sn", ["Throughput_50mb"],linewidth=3,figsize=(21,13))
plt.xlabel("Time(s)")
plt.ylabel('Throughput (Mbps)')
# Out:
# Text(0, 0.5, 'Throughput (Mbps)')

# %%
df.plot("sn", ["Throughput_100mb"],linewidth=3,figsize=(21,13))
plt.xlabel("Time(s)")
plt.ylabel('Throughput (Mbps)')
# Out:
# Text(0, 0.5, 'Throughput (Mbps)')

# %%
df.plot("sn", ["Throughput_5mb","Throughput_10mb","Throughput_20mb","Throughput_50mb","Throughput_100mb"], figsize=(21,13))
plt.xlabel("Time(s)")
plt.ylabel('Throughput (Mbps)')
plt.legend(loc=0, prop={'size': 26})
