# %%
#Learning Rate = 0.001
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib
from pylab import *
# %matplotlib inline
import matplotlib.pyplot as plt
plt.rcParams.update({'font.size': 40})
#plt.rcParams["font.weight"] = "bold"
#plt.rcParams["axes.labelweight"] = "bold"
rc('axes', linewidth=4)

# %%
df = pd.read_csv('reward_plots_old.csv')

# %%
#pwd

# %%
df.head()
# Out:
#    Timesteps  75% Efficiency: (0.75)  85% Efficiency: (0.85)  \
# 0       2004             -251.000000              -46.950001
# 1       3813             -386.285706              -53.444443
# 2       5158             -362.600006              -57.666668
# 3       6605             -323.200012              -69.754387
# 4       8285             -291.100006              -66.480003
#
#    95% Efficiency: (0.95)
# 0             -126.571426
# 1             -134.769226
# 2             -157.736847
# 3             -164.217392
# 4             -181.185181

# %%
df.plot("Timesteps",["75% Efficiency: (0.75)","85% Efficiency: (0.85)", "95% Efficiency: (0.95)"],figsize=(21,16))
plt.xlabel("Timesteps")
plt.ylabel('Mean Reward')
plt.xlim([0, 50000, 350000])
#plt.legend(loc=0, prop={'size': 26})
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-17-1af7ea1ce2a0> in <module>
#       2 plt.xlabel("Timesteps")
#       3 plt.ylabel('Mean Reward')
# ----> 4 plt.xlim([0, 50000, 400000])
#       5 #plt.legend(loc=0, prop={'size': 26})
#
# ~/opt/anaconda3/lib/python3.7/site-packages/matplotlib/pyplot.py in xlim(*args, **kwargs)
#    1687     if not args and not kwargs:
#    1688         return ax.get_xlim()
# -> 1689     ret = ax.set_xlim(*args, **kwargs)
#    1690     return ret
#    1691
#
# ~/opt/anaconda3/lib/python3.7/site-packages/matplotlib/axes/_base.py in set_xlim(self, left, right, emit, auto, xmin, xmax)
#    3513         """
#    3514         if right is None and np.iterable(left):
# -> 3515             left, right = left
#    3516         if xmin is not None:
#    3517             if left is not None:
#
# ...

# %%
# df.plot(x='Timesteps',y='ddpg_10',color='red')

# df.plot(x='Timesteps',y='ddpg_10',color='red')
